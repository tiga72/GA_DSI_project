# %%
import keras

import pandas as pd
from pandas.plotting import lag_plot

import scipy.stats
import pylab
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense # final output layer
from keras.layers import LSTM
from keras.models import load_model
from statsmodels.tools.eval_measures import rmse

# %%
gold = pd.read_csv('../data/gold_clean.csv',parse_dates=['Date'], index_col='Date')
gold.index.freq='MS'

# %%
gold.index
# Out:
# DatetimeIndex(['1971-01-01', '1971-02-01', '1971-03-01', '1971-04-01',
#                '1971-05-01', '1971-06-01', '1971-07-01', '1971-08-01',
#                '1971-09-01', '1971-10-01',
#                ...
#                '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01',
#                '2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01',
#                '2020-03-01', '2020-04-01'],
#               dtype='datetime64[ns]', name='Date', length=592, freq='MS')

# %%
gold.spot_gold.plot()

# %%
scipy.stats.probplot(gold.spot_gold, plot = pylab)
pylab.show()

# %%
train = gold[:580]
test = gold[580:]

# %% [markdown]
# ### Data Scaling

# %%
scaler = MinMaxScaler()

# WE ONLY FIT TO TRAININ DATA, OTHERWISE WE ARE CHEATING ASSUMING INFO ABOUT TEST SET
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# ### Time Series Generator
# This class takes in a sequence of data-points gathered at equal intervals, along with time series parameters such as stride, length of history, etc., to produce batches for training/validation.

# %%
length = 12 # Length of the output sequences (in number of timesteps)
batch_size = 1 #Number of timeseries samples in each batch
train_generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=batch_size)

# %%
n_features = 1
n_input = 12

model = Sequential()
model.add(LSTM(200,activation='relu', 
               input_shape=(length,n_features))) 
# '200' input to LSTM is more of a trail and error and it depends on ur data
model.add(Dense(1)) # aggregates all neutrons into a single output
model.compile(optimizer='adam',loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 200)               161600
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(train_generator,epochs=25)
# Out:
# Epoch 1/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0075
# Epoch 2/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0022
# Epoch 3/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0014
# Epoch 4/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0014
# Epoch 5/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0010
# Epoch 6/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0011
# Epoch 7/30
# 568/568 [==============================] - 3s 5ms/step - loss: 0.0012
# Epoch 8/30
# 568/568 [==============================] - 3s 5ms/step - loss: 9.9757e-04
# Epoch 9/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.9274e-04
# Epoch 10/30
# 568/568 [==============================] - 3s 5ms/step - loss: 8.5055e-04
# Epoch 11/30
# 568/568 [==============================] - 3s 5ms/step - loss: 8.3582e-04
# Epoch 12/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.2471e-04
# Epoch 13/30
# 568/568 [==============================] - 3s 5ms/step - loss: 8.6616e-04
# Epoch 14/30
# 568/568 [==============================] - 3s 5ms/step - loss: 8.2789e-04
# Epoch 15/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.5838e-04
# Epoch 16/30
# 568/568 [==============================] - 3s 5ms/step - loss: 8.3478e-04
# Epoch 17/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.9996e-04
# Epoch 18/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.7464e-04
# Epoch 19/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.3667e-04
# Epoch 20/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.5486e-04
# Epoch 21/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.4202e-04
# Epoch 22/30
# 568/568 [==============================] - 3s 5ms/step - loss: 5.8635e-04
# Epoch 23/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.3613e-04
# Epoch 24/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.4288e-04
# Epoch 25/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.4884e-04
# Epoch 26/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.4640e-04
# Epoch 27/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.6003e-04
# Epoch 28/30
# 568/568 [==============================] - 3s 5ms/step - loss: 5.9731e-04
# Epoch 29/30
# 568/568 [==============================] - 3s 5ms/step - loss: 7.1154e-04
# Epoch 30/30
# 568/568 [==============================] - 3s 5ms/step - loss: 6.1090e-04

# %%
loss1 = model.history.history['loss']
plt.plot(range(len(loss1)),loss1)

# %%
### Forecast using RNN model

# %%
# placeholder for predictions
test_prediction = []

# last n_inputs from the training set
first_eval_batch = scaled_train[-n_input:]
# reshape this to the format RNN wants(same format as TimGenerator)
current_batch = first_eval_batch.reshape((1,n_input,n_features))


# can fcast for longer period by changing range(len(test))
# But if too long into future, it can be fcasting on fcasted data which will result in noisy predictions
# fcast for the test preiod only
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0] # one time step ahead of historical 12 pts
    test_prediction.append(current_pred)
    
# current_batch.ndim = 3 . example array([[[0.63432772]...[0.5584238 ]]]), notice the 3 levels of brackets. Deep!
# np.append adds the 'current_pred' into current_batch at middle array by specifying posn using 'axis=1'
# current_batch.shape is 1,12,1
# current_batch[:,1:,:], first and 3rd colon means all
# current_batch[:,1:,:].shape is 1,11,1
# shifts the array forward by 1 'current_batch[:,1:,:]'
# updates 'current_pred' by inserting it at the top/first/front value of the current_batch  
    
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_prediction)

# %%
test['Predictions'] = true_predictions
# Out:
# C:\Users\LES\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test.plot(figsize=(10,6))

# %%
error_may18_to_apr20 = rmse(test['spot_gold'],test['Predictions'])
print(f'Train model RMSE for past 2 years: {error_may18_to_apr20}')
# Out:
# Train model RMSE for past 2 years: 447.4450208734831

# %% [markdown]
# ### Model with full data
#
# Predict next 8 months

# %%
scaler = MinMaxScaler()

# WE ONLY FIT TO TRAININ DATA, OTHERWISE WE ARE CHEATING ASSUMING INFO ABOUT TEST SET
scaler.fit(gold)
# Out:
# MinMaxScaler()

# %%
scaled_gold = scaler.transform(gold)

# %%
length = 8 # Length of the output sequences (in number of timesteps)
batch_size = 1 #Number of timeseries samples in each batch
gold_generator = TimeseriesGenerator(scaled_gold, scaled_gold, length=length, batch_size=batch_size)

# %%
n_features = 1
n_input = 8

model1 = Sequential()
model1.add(LSTM(200,activation='relu', 
               input_shape=(length,n_features))) 
# '200' input to LSTM is more of a trail and error and it depends on ur data
model1.add(Dense(1)) # aggregates all neutrons into a single output
model1.compile(optimizer='adam',loss='mse')

# %%
model1.fit_generator(gold_generator,epochs=30)
# Out:
# Epoch 1/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0043
# Epoch 2/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0020
# Epoch 3/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0020
# Epoch 4/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0012
# Epoch 5/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0012
# Epoch 6/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0014
# Epoch 7/30
# 584/584 [==============================] - 2s 4ms/step - loss: 9.9900e-04
# Epoch 8/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0010
# Epoch 9/30
# 584/584 [==============================] - 2s 4ms/step - loss: 9.3472e-04
# Epoch 10/30
# 584/584 [==============================] - 2s 4ms/step - loss: 9.1614e-04
# Epoch 11/30
# 584/584 [==============================] - 2s 4ms/step - loss: 0.0010
# Epoch 12/30
# 584/584 [==============================] - 2s 4ms/step - loss: 8.0707e-04
# Epoch 13/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.6516e-04
# Epoch 14/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.5976e-04
# Epoch 15/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.5796e-04
# Epoch 16/30
# 584/584 [==============================] - 2s 4ms/step - loss: 8.1563e-04
# Epoch 17/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.9421e-04
# Epoch 18/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.8500e-04
# Epoch 19/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.0451e-04
# Epoch 20/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.5959e-04
# Epoch 21/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.4686e-04
# Epoch 22/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.6400e-04
# Epoch 23/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.9159e-04
# Epoch 24/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.5741e-04
# Epoch 25/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.0834e-04
# Epoch 26/30
# 584/584 [==============================] - 2s 4ms/step - loss: 7.0852e-04
# Epoch 27/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.6961e-04
# Epoch 28/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.6706e-04
# Epoch 29/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.9258e-04
# Epoch 30/30
# 584/584 [==============================] - 2s 4ms/step - loss: 6.5659e-04

# %%
loss1 = model1.history.history['loss']
plt.plot(range(len(loss1)),loss1)

# %%
test_prediction1 = []

# last n_inputs from the training set
first_eval_batch1 = scaled_gold[-n_input:]
# reshape this to the format RNN wants(same format as TimGenerator)
current_batch1 = first_eval_batch1.reshape((1,n_input,n_features))


# can fcast for longer period by changing range(len(test))
# But if too long into future, it can be fcasting on fcasted data which will result in noisy predictions
# fcast for the test preiod only
for i in range(8):
    current_pred1 = model1.predict(current_batch1)[0] # one time step ahead of historical 12 pts
    test_prediction1.append(current_pred1)
    
# current_batch.ndim = 3 . example array([[[0.63432772]...[0.5584238 ]]]), notice the 3 levels of brackets. Deep!
# np.append adds the 'current_pred' into current_batch at middle array by specifying posn using 'axis=1'
# current_batch.shape is 1,12,1
# current_batch[:,1:,:], first and 3rd colon means all
# current_batch[:,1:,:].shape is 1,11,1
# shifts the array forward by 1 'current_batch[:,1:,:]'
# updates 'current_pred' by inserting it at the top/first/front value of the current_batch  
    
    current_batch1 = np.append(current_batch1[:,1:,:],[[current_pred1]],axis=1)

# %%
true_predictions1 = scaler.inverse_transform(test_prediction1)

# %%
len(test_prediction1)
# Out:
# 8

# %%
date_list = pd.date_range('2020-05-01','2020-12-01', 
              freq='MS').strftime("%Y-%m-%d").tolist()

# %%
df1 = pd.DataFrame({
    'Date':date_list})

# %%
df1.head(20)
# Out:
#          Date
# 0  2020-05-01
# 1  2020-06-01
# 2  2020-07-01
# 3  2020-08-01
# 4  2020-09-01
# 5  2020-10-01
# 6  2020-11-01
# 7  2020-12-01

# %%
gold.head()
# Out:
#             spot_gold
# Date
# 1971-01-01      38.05
# 1971-02-01      38.80
# 1971-03-01      38.88
# 1971-04-01      39.70
# 1971-05-01      40.84

# %%
df1['spot_gold'] = true_predictions1

# %%
df1['Date']= pd.to_datetime(df1['Date'])
df1.set_index('Date', inplace=True)
df1.index.freq='MS'

# %%
gold1 = pd.concat([gold,df1])

# %%
plt.plot(gold['spot_gold'],'g')
plt.plot(df1['spot_gold'],'r')
